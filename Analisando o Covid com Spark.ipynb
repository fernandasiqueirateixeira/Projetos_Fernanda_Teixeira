# %% [markdown]
# # Analisando o COVID19 com Spark

# %% [markdown]
# Como exercício e treinamento de meus estudos, segue pequena análise referente ao assunto mais comentado de 2020, o novo corona vírus. O notebook ainda está em testes e poderá ser aprimorado/atualizado.
#
# OBS: Este notebook foi desenvolvido na plataforma Databricks e por isso permite alguns códigos abaixo.

# %% [markdown]
# **Fernanda de Siqueira Teixeira**

# %% [markdown]
# #### Utilizando a base do covid disponivel em: https://drive.google.com/file/d/1ZOcIJslOAdgMgltQrm9hEzCzO13pOmgw/view?usp=sharing

# %% [markdown]
# Colunas:
#
# **city:** nome do município (pode estar em branco quando o registro é referente ao estado, pode ser preenchido com Importados/Indefinidos também).
#
# **city_ibge_code:** código IBGE do local.
#
# **date:** data de coleta dos dados no formato YYYY-MM-DD.
#
# **epidemiological_week:** número da semana epidemiológica.
#
# **estimated_population_2019: **população estimada para esse município/estado em 2019, segundo o IBGE (acesse o script que faz o download e conversão dos dados de população).
#
# **is_last:** campo pré-computado que diz se esse registro é o mais novo para esse local, pode ser True ou False (caso filtre por esse campo, use is_last=True ou is_last=False, não use o valor em minúsculas).
#
# **is_repeated:** campo pré-computado que diz se as informações nesse registro foram publicadas pela Secretaria Estadual de Saúde no dia date ou se o dado é repetido do último dia em que o dado está disponível (igual ou anterior a date). Isso ocorre pois nem todas as secretarias publicam boletins todos os dias. Veja também o campo last_available_date.
#
# **last_available_confirmed:** número de casos confirmados do último dia disponível igual ou anterior à data date.
#
# **last_available_confirmed_per_100k_inhabitants:** número de casos confirmados por 100.000 habitantes do último dia disponível igual ou anterior à data date.
#
# **last_available_date:** data da qual o dado se refere.
#
# **last_available_death_rate:** taxa de mortalidade (mortes / confirmados) do último dia disponível igual ou anterior à data date.
#
# **last_available_deaths:** número de mortes do último dia disponível igual ou anterior à data date.
#
# **order_for_place:** número que identifica a ordem do registro para este local. O registro referente ao primeiro boletim em que esse local aparecer será contabilizado como 1 e os demais boletins incrementarão esse valor.
#
# **place_type:** tipo de local que esse registro descreve, pode ser city ou state.
#
# **state:** sigla da unidade federativa, exemplo: SP.
#
# **new_confirmed:** número de novos casos confirmados desde o último dia (note que caso is_repeated seja True, esse valor sempre será 0 e que esse valor pode ser negativo caso a SES remaneje os casos desse município para outro).
#
# **new_deaths:** número de novos óbitos desde o último dia (note que caso is_repeated seja True, esse valor sempre será 0 e que esse valor pode ser negativo caso a SES remaneje os casos desse município para outro).

# %% [markdown]
# **Desenvolvimento**

# %%
#importando
from pyspark.sql import functions as f
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Após salvar os arquivos baixados utilizaremos a função spark.read_csv para carregar a base de dados. Nomearemos como df.

# %%
# lendo o arquivo csv
df = spark.read.csv("/FileStore/tables/covid19.csv", header=True,inferSchema=True)
df.limit(10).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>epidemiological_week</th>
#       <th>date</th>
#       <th>order_for_place</th>
#       <th>state</th>
#       <th>city</th>
#       <th>city_ibge_code</th>
#       <th>place_type</th>
#       <th>last_available_confirmed</th>
#       <th>last_available_confirmed_per_100k_inhabitants</th>
#       <th>new_confirmed</th>
#       <th>last_available_deaths</th>
#       <th>new_deaths</th>
#       <th>last_available_death_rate</th>
#       <th>estimated_population_2019</th>
#       <th>is_last</th>
#       <th>is_repeated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>63</td>
#       <td>MG</td>
#       <td>Abadia dos Dourados</td>
#       <td>3100104</td>
#       <td>city</td>
#       <td>5</td>
#       <td>71.54099</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>6989</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>89</td>
#       <td>MG</td>
#       <td>Abaeté</td>
#       <td>3100203</td>
#       <td>city</td>
#       <td>20</td>
#       <td>86.06963</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>23237</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>32</td>
#       <td>MG</td>
#       <td>Abre Campo</td>
#       <td>3100302</td>
#       <td>city</td>
#       <td>9</td>
#       <td>66.89460</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>13454</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>22</td>
#       <td>MG</td>
#       <td>Acaiaca</td>
#       <td>3100401</td>
#       <td>city</td>
#       <td>11</td>
#       <td>275.41312</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0.0909</td>
#       <td>3994</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>52</td>
#       <td>MG</td>
#       <td>Açucena</td>
#       <td>3100500</td>
#       <td>city</td>
#       <td>18</td>
#       <td>190.07392</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0.0556</td>
#       <td>9470</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>41</td>
#       <td>MG</td>
#       <td>Água Comprida</td>
#       <td>3100708</td>
#       <td>city</td>
#       <td>2</td>
#       <td>100.05003</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>1999</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>22</td>
#       <td>MG</td>
#       <td>Aguanil</td>
#       <td>3100807</td>
#       <td>city</td>
#       <td>5</td>
#       <td>111.45787</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>4486</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>36</td>
#       <td>MG</td>
#       <td>Águas Formosas</td>
#       <td>3100906</td>
#       <td>city</td>
#       <td>18</td>
#       <td>93.71583</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>19207</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>51</td>
#       <td>MG</td>
#       <td>Águas Vermelhas</td>
#       <td>3101003</td>
#       <td>city</td>
#       <td>25</td>
#       <td>184.65175</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>13539</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>67</td>
#       <td>MG</td>
#       <td>Aimorés</td>
#       <td>3101102</td>
#       <td>city</td>
#       <td>108</td>
#       <td>429.13339</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>25167</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Para visualizar as colunas iremos usar a função .columns que permite verificar os nomes de todas as colunas da base de dados.

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[182]: [&#39;epidemiological_week&#39;,
#  &#39;date&#39;,
#  &#39;order_for_place&#39;,
#  &#39;state&#39;,
#  &#39;city&#39;,
#  &#39;city_ibge_code&#39;,
#  &#39;place_type&#39;,
#  &#39;last_available_confirmed&#39;,
#  &#39;last_available_confirmed_per_100k_inhabitants&#39;,
#  &#39;new_confirmed&#39;,
#  &#39;last_available_deaths&#39;,
#  &#39;new_deaths&#39;,
#  &#39;last_available_death_rate&#39;,
#  &#39;estimated_population_2019&#39;,
#  &#39;is_last&#39;,
#  &#39;is_repeated&#39;]</div>

# %% [markdown]
# Para verificar os números de itens distintos iremos usar a função .distinct().count()

# %%
df.distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[183]: 38285</div>

# %% [markdown]
# Verificando se existem dados nulos. Caso sim, iremos remove-los.

# %%
#verificando se existem dados nulos 
display(df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>epidemiological_week</th><th>date</th><th>order_for_place</th><th>state</th><th>city</th><th>city_ibge_code</th><th>place_type</th><th>last_available_confirmed</th><th>last_available_confirmed_per_100k_inhabitants</th><th>new_confirmed</th><th>last_available_deaths</th><th>new_deaths</th><th>last_available_death_rate</th><th>estimated_population_2019</th></tr></thead><tbody><tr><td>count</td><td>38285</td><td>38285</td><td>38285</td><td>38285</td><td>38161</td><td>38174</td><td>38285</td><td>38285</td><td>37090</td><td>38285</td><td>38285</td><td>38285</td><td>38285</td><td>38174</td></tr><tr><td>mean</td><td>23.506098994384224</td><td>null</td><td>33.4752775238344</td><td>null</td><td>null</td><td>3126425.170246765</td><td>null</td><td>74.75549170693483</td><td>90.68026332030466</td><td>3.4929606895651037</td><td>1.761159723129163</td><td>0.07548648295677159</td><td>0.048336460754865404</td><td>114430.32849583487</td></tr><tr><td>stddev</td><td>3.5248488249073042</td><td>null</td><td>24.56844522848255</td><td>null</td><td>null</td><td>179660.06893933652</td><td>null</td><td>1185.067677288254</td><td>156.11884223016364</td><td>61.901165522080724</td><td>26.004373845729432</td><td>1.220983818617959</td><td>0.16201736795455784</td><td>1212245.7370699628</td></tr><tr><td>min</td><td>11</td><td>2020-03-08</td><td>1</td><td>MG</td><td>Abadia dos Dourados</td><td>31</td><td>city</td><td>0</td><td>0.00472</td><td>-185</td><td>0</td><td>-2</td><td>0.0</td><td>1502</td></tr><tr><td>max</td><td>28</td><td>2020-07-09</td><td>124</td><td>MG</td><td>Águas Vermelhas</td><td>3172202</td><td>state</td><td>66864</td><td>2713.07909</td><td>6122</td><td>1445</td><td>90</td><td>1.0</td><td>21168791</td></tr></tbody></table></div>

# %% [markdown]
# Observa-se que as colunas que possuem dados faltantes são:
# - **city**:  38161 dados do tipo object
# - **city_ibge_code**: 38174 dados do tipo  float64
# - **last_available_confirmed_per_100k_inhabitants**: 37090 dados do tipo  float64
# - **estimated_population_2019**: 38174 dados do tipo float64

# %%
# Excluindo os dados faltantes utilizando subset
data = df.dropna(subset=['city', 'city_ibge_code', 'estimated_population_2019', 'last_available_confirmed_per_100k_inhabitants'])
data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[185]: 36966</div>

# %%
# Como optamos por excluir todos os dados faltantes, podemos utilizar essa maneira que é mais fácil 
df = df.dropna(how='any')
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[186]: 36966</div>

# %% [markdown]
# Mostrando o Schema do DataFrame. Isso é importante pois conseguimos verificar o tipo da coluna.

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- epidemiological_week: integer (nullable = true)
# -- date: string (nullable = true)
# -- order_for_place: integer (nullable = true)
# -- state: string (nullable = true)
# -- city: string (nullable = true)
# -- city_ibge_code: integer (nullable = true)
# -- place_type: string (nullable = true)
# -- last_available_confirmed: integer (nullable = true)
# -- last_available_confirmed_per_100k_inhabitants: double (nullable = true)
# -- new_confirmed: integer (nullable = true)
# -- last_available_deaths: integer (nullable = true)
# -- new_deaths: integer (nullable = true)
# -- last_available_death_rate: double (nullable = true)
# -- estimated_population_2019: integer (nullable = true)
# -- is_last: boolean (nullable = true)
# -- is_repeated: boolean (nullable = true)
#
# </div>

# %% [markdown]
# Para visualizar os dados vamos usar a função .head() que permitirá verificar as 5 primeiras linhas como um vetor da base de dados.

# %%
df.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[188]: [Row(epidemiological_week=28, date=&#39;2020-07-09&#39;, order_for_place=63, state=&#39;MG&#39;, city=&#39;Abadia dos Dourados&#39;, city_ibge_code=3100104, place_type=&#39;city&#39;, last_available_confirmed=5, last_available_confirmed_per_100k_inhabitants=71.54099, new_confirmed=0, last_available_deaths=0, new_deaths=0, last_available_death_rate=0.0, estimated_population_2019=6989, is_last=True, is_repeated=False),
#  Row(epidemiological_week=28, date=&#39;2020-07-09&#39;, order_for_place=89, state=&#39;MG&#39;, city=&#39;Abaeté&#39;, city_ibge_code=3100203, place_type=&#39;city&#39;, last_available_confirmed=20, last_available_confirmed_per_100k_inhabitants=86.06963, new_confirmed=0, last_available_deaths=0, new_deaths=0, last_available_death_rate=0.0, estimated_population_2019=23237, is_last=True, is_repeated=False),
#  Row(epidemiological_week=28, date=&#39;2020-07-09&#39;, order_for_place=32, state=&#39;MG&#39;, city=&#39;Abre Campo&#39;, city_ibge_code=3100302, place_type=&#39;city&#39;, last_available_confirmed=9, last_available_confirmed_per_100k_inhabitants=66.8946, new_confirmed=0, last_available_deaths=0, new_deaths=0, last_available_death_rate=0.0, estimated_population_2019=13454, is_last=True, is_repeated=False),
#  Row(epidemiological_week=28, date=&#39;2020-07-09&#39;, order_for_place=22, state=&#39;MG&#39;, city=&#39;Acaiaca&#39;, city_ibge_code=3100401, place_type=&#39;city&#39;, last_available_confirmed=11, last_available_confirmed_per_100k_inhabitants=275.41312, new_confirmed=0, last_available_deaths=1, new_deaths=0, last_available_death_rate=0.0909, estimated_population_2019=3994, is_last=True, is_repeated=False),
#  Row(epidemiological_week=28, date=&#39;2020-07-09&#39;, order_for_place=52, state=&#39;MG&#39;, city=&#39;Açucena&#39;, city_ibge_code=3100500, place_type=&#39;city&#39;, last_available_confirmed=18, last_available_confirmed_per_100k_inhabitants=190.07392, new_confirmed=2, last_available_deaths=1, new_deaths=0, last_available_death_rate=0.0556, estimated_population_2019=9470, is_last=True, is_repeated=False)]</div>

# %% [markdown]
# Para visualizar os dados em formato de Pandas DataFrame vamos usar a função .toPandas(), limitando a 10 linhas

# %%
df.limit(10).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>epidemiological_week</th>
#       <th>date</th>
#       <th>order_for_place</th>
#       <th>state</th>
#       <th>city</th>
#       <th>city_ibge_code</th>
#       <th>place_type</th>
#       <th>last_available_confirmed</th>
#       <th>last_available_confirmed_per_100k_inhabitants</th>
#       <th>new_confirmed</th>
#       <th>last_available_deaths</th>
#       <th>new_deaths</th>
#       <th>last_available_death_rate</th>
#       <th>estimated_population_2019</th>
#       <th>is_last</th>
#       <th>is_repeated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>63</td>
#       <td>MG</td>
#       <td>Abadia dos Dourados</td>
#       <td>3100104</td>
#       <td>city</td>
#       <td>5</td>
#       <td>71.54099</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>6989</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>89</td>
#       <td>MG</td>
#       <td>Abaeté</td>
#       <td>3100203</td>
#       <td>city</td>
#       <td>20</td>
#       <td>86.06963</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>23237</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>32</td>
#       <td>MG</td>
#       <td>Abre Campo</td>
#       <td>3100302</td>
#       <td>city</td>
#       <td>9</td>
#       <td>66.89460</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>13454</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>22</td>
#       <td>MG</td>
#       <td>Acaiaca</td>
#       <td>3100401</td>
#       <td>city</td>
#       <td>11</td>
#       <td>275.41312</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0.0909</td>
#       <td>3994</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>52</td>
#       <td>MG</td>
#       <td>Açucena</td>
#       <td>3100500</td>
#       <td>city</td>
#       <td>18</td>
#       <td>190.07392</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0.0556</td>
#       <td>9470</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>41</td>
#       <td>MG</td>
#       <td>Água Comprida</td>
#       <td>3100708</td>
#       <td>city</td>
#       <td>2</td>
#       <td>100.05003</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>1999</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>22</td>
#       <td>MG</td>
#       <td>Aguanil</td>
#       <td>3100807</td>
#       <td>city</td>
#       <td>5</td>
#       <td>111.45787</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>4486</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>36</td>
#       <td>MG</td>
#       <td>Águas Formosas</td>
#       <td>3100906</td>
#       <td>city</td>
#       <td>18</td>
#       <td>93.71583</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>19207</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>51</td>
#       <td>MG</td>
#       <td>Águas Vermelhas</td>
#       <td>3101003</td>
#       <td>city</td>
#       <td>25</td>
#       <td>184.65175</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>13539</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>28</td>
#       <td>2020-07-09</td>
#       <td>67</td>
#       <td>MG</td>
#       <td>Aimorés</td>
#       <td>3101102</td>
#       <td>city</td>
#       <td>108</td>
#       <td>429.13339</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>25167</td>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Mostrando o sumário do DataFrame

# %%
# Demonstra dados estátisticos sobre o DataFrame
display(df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>epidemiological_week</th><th>date</th><th>order_for_place</th><th>state</th><th>city</th><th>city_ibge_code</th><th>place_type</th><th>last_available_confirmed</th><th>last_available_confirmed_per_100k_inhabitants</th><th>new_confirmed</th><th>last_available_deaths</th><th>new_deaths</th><th>last_available_death_rate</th><th>estimated_population_2019</th></tr></thead><tbody><tr><td>count</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td><td>36966</td></tr><tr><td>mean</td><td>23.512741438078233</td><td>null</td><td>33.914705404966725</td><td>null</td><td>null</td><td>3136545.224801169</td><td>null</td><td>38.202645674403506</td><td>90.80157201617978</td><td>1.7965968728020343</td><td>0.8949845804252556</td><td>0.038548936860899205</td><td>0.049938459665639305</td><td>46745.24866093167</td></tr><tr><td>stddev</td><td>3.5063101270362544</td><td>null</td><td>24.437566273487075</td><td>null</td><td>null</td><td>20665.125182452684</td><td>null</td><td>242.80243803143273</td><td>156.29838910234386</td><td>19.193699378111077</td><td>5.254168358399579</td><td>0.3706413685439136</td><td>0.1646449289042188</td><td>160185.84836741397</td></tr><tr><td>min</td><td>11</td><td>2020-03-08</td><td>1</td><td>MG</td><td>Abadia dos Dourados</td><td>3100104</td><td>city</td><td>1</td><td>0.03981</td><td>-127</td><td>0</td><td>-2</td><td>0.0</td><td>1502</td></tr><tr><td>max</td><td>28</td><td>2020-07-09</td><td>124</td><td>MG</td><td>Águas Vermelhas</td><td>3172202</td><td>city</td><td>9361</td><td>2713.07909</td><td>2756</td><td>223</td><td>23</td><td>1.0</td><td>2512070</td></tr></tbody></table></div>

# %% [markdown]
# Para mostrar o sumário de apenas as colunas de formato inteiro, double ou float, há duas maneiras:

# %%
#Maneira 1: Excluindo da visualização as colunas que não são desse formato
df.select(list(set(df.columns) - set(['date', 'city', 'state']))).describe().toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>new_confirmed</th>
#       <th>last_available_confirmed</th>
#       <th>epidemiological_week</th>
#       <th>estimated_population_2019</th>
#       <th>new_deaths</th>
#       <th>place_type</th>
#       <th>last_available_deaths</th>
#       <th>order_for_place</th>
#       <th>last_available_death_rate</th>
#       <th>last_available_confirmed_per_100k_inhabitants</th>
#       <th>city_ibge_code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>count</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>mean</td>
#       <td>1.7965968728020343</td>
#       <td>38.202645674403506</td>
#       <td>23.512741438078233</td>
#       <td>46745.24866093167</td>
#       <td>0.038548936860899205</td>
#       <td>None</td>
#       <td>0.8949845804252556</td>
#       <td>33.914705404966725</td>
#       <td>0.049938459665639305</td>
#       <td>90.80157201617978</td>
#       <td>3136545.224801169</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>stddev</td>
#       <td>19.193699378111077</td>
#       <td>242.80243803143273</td>
#       <td>3.5063101270362544</td>
#       <td>160185.84836741397</td>
#       <td>0.3706413685439136</td>
#       <td>None</td>
#       <td>5.254168358399579</td>
#       <td>24.437566273487075</td>
#       <td>0.1646449289042188</td>
#       <td>156.29838910234386</td>
#       <td>20665.125182452684</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>min</td>
#       <td>-127</td>
#       <td>1</td>
#       <td>11</td>
#       <td>1502</td>
#       <td>-2</td>
#       <td>city</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0</td>
#       <td>0.03981</td>
#       <td>3100104</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>max</td>
#       <td>2756</td>
#       <td>9361</td>
#       <td>28</td>
#       <td>2512070</td>
#       <td>23</td>
#       <td>city</td>
#       <td>223</td>
#       <td>124</td>
#       <td>1.0</td>
#       <td>2713.07909</td>
#       <td>3172202</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Maneira 2: Selecionando apenas as colunas numéricas
numericalColumns = [campo for (campo,tipo) in df.dtypes if tipo == 'int' or tipo == 'double']
df.select(numericalColumns).describe().toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>epidemiological_week</th>
#       <th>order_for_place</th>
#       <th>city_ibge_code</th>
#       <th>last_available_confirmed</th>
#       <th>last_available_confirmed_per_100k_inhabitants</th>
#       <th>new_confirmed</th>
#       <th>last_available_deaths</th>
#       <th>new_deaths</th>
#       <th>last_available_death_rate</th>
#       <th>estimated_population_2019</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>count</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#       <td>36966</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>mean</td>
#       <td>23.512741438078233</td>
#       <td>33.914705404966725</td>
#       <td>3136545.224801169</td>
#       <td>38.202645674403506</td>
#       <td>90.80157201617978</td>
#       <td>1.7965968728020343</td>
#       <td>0.8949845804252556</td>
#       <td>0.038548936860899205</td>
#       <td>0.049938459665639305</td>
#       <td>46745.24866093167</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>stddev</td>
#       <td>3.5063101270362544</td>
#       <td>24.437566273487075</td>
#       <td>20665.125182452684</td>
#       <td>242.80243803143273</td>
#       <td>156.29838910234386</td>
#       <td>19.193699378111077</td>
#       <td>5.254168358399579</td>
#       <td>0.3706413685439136</td>
#       <td>0.1646449289042188</td>
#       <td>160185.84836741397</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>min</td>
#       <td>11</td>
#       <td>1</td>
#       <td>3100104</td>
#       <td>1</td>
#       <td>0.03981</td>
#       <td>-127</td>
#       <td>0</td>
#       <td>-2</td>
#       <td>0.0</td>
#       <td>1502</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>max</td>
#       <td>28</td>
#       <td>124</td>
#       <td>3172202</td>
#       <td>9361</td>
#       <td>2713.07909</td>
#       <td>2756</td>
#       <td>223</td>
#       <td>23</td>
#       <td>1.0</td>
#       <td>2512070</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# **Agora vamos para alguns desafios:**
#
# **1**.Mostrando a média de confirmados por 100k habitantes e media da taxa de mortalidade

# %%
df.select(f.mean('last_available_death_rate'), f.mean('last_available_confirmed_per_100k_inhabitants')).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>avg(last_available_death_rate)</th>
#       <th>avg(last_available_confirmed_per_100k_inhabitants)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.049938</td>
#       <td>90.801572</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# **2**.Mostrando a razão entre o ultimo número de confirmados e a população da cidade -> last_available_confirmed/estimated_population_2019

# %%
df.withColumn('razao_mortos_confirmados', f.col('last_available_confirmed')/f.col('estimated_population_2019')).select('razao_mortos_confirmados').toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>razao_mortos_confirmados</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.000715</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.000861</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.000669</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.002754</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.001901</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>36961</th>
#       <td>0.000004</td>
#     </tr>
#     <tr>
#       <th>36962</th>
#       <td>0.000004</td>
#     </tr>
#     <tr>
#       <th>36963</th>
#       <td>0.000004</td>
#     </tr>
#     <tr>
#       <th>36964</th>
#       <td>0.000004</td>
#     </tr>
#     <tr>
#       <th>36965</th>
#       <td>0.000004</td>
#     </tr>
#   </tbody>
# </table>
# <p>36966 rows × 1 columns</p>
# </div>

# %% [markdown]
# **3**.Qual o cidade teve o maior número de novos casos(new_confimed)?

# %%
df.filter(f.col('new_confirmed') == df.select(f.max('new_confirmed')).collect()[0][0]).select('city').toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Uberlândia</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# **4**.Em qual semana epidemiologica isso aconteceu?

# %%
df.filter(f.col('new_confirmed') == df.select(f.max('new_confirmed')).collect()[0][0]).select('epidemiological_week').toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>epidemiological_week</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>26</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# **5**.Qual a média de novos casos por cidade?

# %%
df.groupBy('city').agg(f.mean('new_confirmed').alias('media_novos_casos')).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>city</th>
#       <th>media_novos_casos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Fronteira</td>
#       <td>0.283582</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Piranguinho</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Presidente Olegário</td>
#       <td>0.758621</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Rio Novo</td>
#       <td>0.174603</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Carrancas</td>
#       <td>0.038462</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>749</th>
#       <td>Reduto</td>
#       <td>0.785714</td>
#     </tr>
#     <tr>
#       <th>750</th>
#       <td>Glaucilândia</td>
#       <td>0.222222</td>
#     </tr>
#     <tr>
#       <th>751</th>
#       <td>Pedra Dourada</td>
#       <td>0.075758</td>
#     </tr>
#     <tr>
#       <th>752</th>
#       <td>Santo Antônio do Amparo</td>
#       <td>1.160714</td>
#     </tr>
#     <tr>
#       <th>753</th>
#       <td>São João do Paraíso</td>
#       <td>0.307692</td>
#     </tr>
#   </tbody>
# </table>
# <p>754 rows × 2 columns</p>
# </div>

# %% [markdown]
# **6**.Ordenando de forma descendente a média dos novos casos por cidade

# %%
df.groupBy('city').agg(f.mean('new_confirmed').alias('media_novos_casos')).orderBy(f.desc('media_novos_casos')).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>city</th>
#       <th>media_novos_casos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Belo Horizonte</td>
#       <td>80.698276</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Uberlândia</td>
#       <td>72.869565</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Ipatinga</td>
#       <td>26.000000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Juiz de Fora</td>
#       <td>19.720339</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Governador Valadares</td>
#       <td>16.528302</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>749</th>
#       <td>Guarará</td>
#       <td>0.018182</td>
#     </tr>
#     <tr>
#       <th>750</th>
#       <td>Ilicínea</td>
#       <td>0.015625</td>
#     </tr>
#     <tr>
#       <th>751</th>
#       <td>Divisa Nova</td>
#       <td>0.014085</td>
#     </tr>
#     <tr>
#       <th>752</th>
#       <td>Icaraí de Minas</td>
#       <td>0.014085</td>
#     </tr>
#     <tr>
#       <th>753</th>
#       <td>Divinésia</td>
#       <td>0.010526</td>
#     </tr>
#   </tbody>
# </table>
# <p>754 rows × 2 columns</p>
# </div>

# %% [markdown]
# **7**.Gerando a relação ordenada de forma descendente entre a media de novos casos e a população da cidade

# %%
df.groupBy('city').agg(f.mean('new_confirmed').alias('media_novos_casos'), 
                                  f.mean('estimated_population_2019').alias('populacao'))\
                                  .withColumn('razao_casos_por', f.col('media_novos_casos')/f.col('populacao'))\
                                  .orderBy(f.desc('razao_casos_por')).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>city</th>
#       <th>media_novos_casos</th>
#       <th>populacao</th>
#       <th>razao_casos_por</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bandeira</td>
#       <td>4.100000</td>
#       <td>4795.0</td>
#       <td>0.000855</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Morada Nova de Minas</td>
#       <td>7.500000</td>
#       <td>8863.0</td>
#       <td>0.000846</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Albertina</td>
#       <td>2.000000</td>
#       <td>3007.0</td>
#       <td>0.000665</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Comendador Gomes</td>
#       <td>1.923077</td>
#       <td>3111.0</td>
#       <td>0.000618</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Alvarenga</td>
#       <td>2.000000</td>
#       <td>3907.0</td>
#       <td>0.000512</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>749</th>
#       <td>Francisco Badaró</td>
#       <td>0.020833</td>
#       <td>10332.0</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <th>750</th>
#       <td>Alterosa</td>
#       <td>0.027778</td>
#       <td>14466.0</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <th>751</th>
#       <td>Igaratinga</td>
#       <td>0.018182</td>
#       <td>10860.0</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <th>752</th>
#       <td>Ilicínea</td>
#       <td>0.015625</td>
#       <td>12375.0</td>
#       <td>0.000001</td>
#     </tr>
#     <tr>
#       <th>753</th>
#       <td>Icaraí de Minas</td>
#       <td>0.014085</td>
#       <td>11990.0</td>
#       <td>0.000001</td>
#     </tr>
#   </tbody>
# </table>
# <p>754 rows × 4 columns</p>
# </div>

# %% [markdown]
# **8**.Em quantos registos o número de novas mortes é maior que 0?

# %%
df.filter('new_deaths > 0').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[200]: 933</div>

# %% [markdown]
# **9**.Quantos % da base tem o número de novas mortes maior que zero?

# %%
df.filter('new_deaths > 0').count()/df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[201]: 0.02523940918682032</div>

# %% [markdown]
# **10**.Mostrando a média de casos novos por dia na semana

# %%
df.groupBy(f.dayofweek('date')).avg('new_confirmed').orderBy('dayofweek(date)').toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dayofweek(date)</th>
#       <th>avg(new_confirmed)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1.453917</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1.016521</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1.008977</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>2.229814</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>2.211666</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>2.904724</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>1.776973</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# **11**.Mostrando a média de novos casos por mês?

# %%
df.groupBy(f.month('date')).avg('new_confirmed').orderBy('month(date)').toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>month(date)</th>
#       <th>avg(new_confirmed)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>0.897010</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>0.479244</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>0.891474</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>1.975673</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7</td>
#       <td>3.324782</td>
#     </tr>
#   </tbody>
# </table>
# </div>
